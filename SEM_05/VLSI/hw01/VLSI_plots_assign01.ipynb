# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
############  Q1.
f = '1.b.dat'
x = np.loadtxt(f)
t = x[:,0]*1e3
plt.plot(t,x[:,1])
plt.plot(t,x[:,3])
plt.plot(t,x[:,0])
plt.title('For 100 Hz')
plt.xlabel('time in ms')
plt.ylabel('V')
plt.legend(['Vin','Vout'])

# %%
f = 'phase.dat'
x = np.loadtxt(f)
print(x.shape)
plt.xscale('log')
plt.grid(True, which="both", ls="-")
plt.plot(x[:,0],x[:,1])


plt.title('Phase characteristics')
plt.xlabel('freq (Hz)')
plt.ylabel('Phase lag (in deg)')
'''
t = x[:,0]*1e3
plt.plot(t,x[:,1])
plt.plot(t,x[:,3])
plt.plot(t,x[:,0])
plt.title('For 100 Hz')
plt.xlabel('time in ms')
plt.ylabel('V')
plt.legend(['Vin','Vout'])
'''
# Out:
# (6001, 2)
# "\nt = x[:,0]*1e3\nplt.plot(t,x[:,1])\nplt.plot(t,x[:,3])\nplt.plot(t,x[:,0])\nplt.title('For 100 Hz')\nplt.xlabel('time in ms')\nplt.ylabel('V')\nplt.legend(['Vin','Vout'])\n"

# %%
f = '3.dat'
x = np.loadtxt(f)
print(x.shape)

plt.plot(x[:,0],x[:,1])
plt.plot(x[:,0],x[:,3])
plt.plot(x[:,0],x[:,2])

plt.legend(['Vin','Vout'])

plt.title('Gain for f = 1kHz : 3')
plt.ylabel('V (t)')
plt.xlabel('time (in sec)')
# Out:
# (508, 4)
# Text(0.5, 0, 'time (in sec)')

# %%
#############
# Q4.
import numpy as np
f1 = '4.1.a.dat'

d = 4


x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)*1e6

x_t = np.split(x,3)
y_t = np.split(y,3)
y_t =y_t

plt.title('nmos long channel : W = 15um, L = 10um')
plt.xlabel('Vds(volts)')
plt.ylabel('Id (in uA)')
plt.plot(x_t[0],y_t[0])
plt.plot(x_t[1],y_t[1])
plt.plot(x_t[2],y_t[2])
plt.grid()
plt.scatter([0.64, 1.14, 1.64], [61.8, 195, 384])
plt.plot([0 ,0.64, 1.14, 1.64], [0, 61.8, 195, 384])


plt.legend(['Vgs = 1V','Vgs = 1.5V','Vgs = 2V', 'Vds = Vgt'])
plt.show()
plt.figure()

# %%
#############
# Q4.
import numpy as np
f1 = '4.1.b.dat'

d = 4


x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)*1e6

x_t = np.split(x,3)
y_t = np.split(y,3)
y_t =y_t

plt.title('nmos Short channel : W = 0.27um, L = 0.18um')
plt.xlabel('Vds(volts)')
plt.ylabel('Id (in uA)')
plt.plot(x_t[0],y_t[0])
plt.plot(x_t[1],y_t[1])
plt.plot(x_t[2],y_t[2])
plt.grid()
plt.scatter([0.64, 1.14, 1.64], [64, 159, 252],color = 'b')
plt.scatter([0.77, 0.61, 0.39], [237, 150, 62],color = 'r')
#plt.plot([0 ,0.64, 1.14, 1.64], [0, 61.8, 195, 384])


plt.legend(['Vgs = 1V','Vgs = 1.5V','Vgs = 2V'])
plt.show()
plt.figure()

# %%
#############
# Q4.    4.d.1
import numpy as np
f1 = '4.d.1.dat'

d = 4


x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)

plt.yscale('log')
plt.title('nmos long channel : W = 15um, L = 10um at  |Vds| = 1.8V')
plt.plot(x,y)
plt.grid(True, which="both", ls="-")

plt.xlabel('Vg (volts)')
plt.ylabel('Id (in A)')
# Out:
# Text(0, 0.5, 'Id (in A)')

# %%
#############
# Q4.    4.d.2
import numpy as np
f1 = '4.d.2.dat'


x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)

plt.yscale('log')
plt.title('nmos short channel : W = 0.27um, L = 0.18um at  |Vds| = 1.8')
plt.plot(x,y)
plt.grid(True, which="both", ls="-")

plt.xlabel('Vg (volts)')
plt.ylabel('Id (in A)')
# Out:
# Text(0, 0.5, 'Id (in A)')

# %%
################  Pmossss

# %%
#############
# Q4.
import numpy as np
f1 = '4.1.b.dat'




x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)*1e6

x_t = np.split(x,3)
y_t = np.split(y,3)
y_t =y_t

plt.title('pmos long channel : W = 15um, L = 10um')
plt.xlabel('Vds(volts)')
plt.ylabel('Id (in uA)')
plt.plot(x_t[0],y_t[0])
plt.plot(x_t[1],y_t[1])
plt.plot(x_t[2],y_t[2])
plt.grid()
plt.scatter([-0.64, -1.14, -1.64], [-13.69, -42, -85])
plt.plot([0,-0.64, -1.14, -1.64], [0,-13.69, -42, -85])


plt.legend(['Vgs = -2V','Vgs = -1.5V','Vgs = -1V', 'Vds = Vgt'])
plt.show()
plt.figure()

# %%
#############
# Q4.
import numpy as np
f1 = '4.1.c.dat'




x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)*1e6

x_t = np.split(x,3)
y_t = np.split(y,3)
y_t =y_t

plt.title('pmos short channel : W = 0.27um, L = 0.18um')
plt.xlabel('Vds(volts)')
plt.ylabel('Id (in uA)')
plt.plot(x_t[0],y_t[0])
plt.plot(x_t[1],y_t[1])
plt.plot(x_t[2],y_t[2])
plt.grid()
plt.scatter([-0.64, -1.14, -1.64], [-16.6, -55.9, -112])



plt.legend(['Vgs = -2V','Vgs = -1.5V','Vgs = -1V', 'Vds = Vgt'])
plt.show()
plt.figure()

# %%
#############
# Q4.    4.d.3
import numpy as np
f = 'k.dat'
x = np.loadtxt(f,usecols = 0)
y = np.loadtxt(f,usecols = 1)
x = np.abs(x)
y = np.abs(y)

plt.yscale('log')
plt.title('pmos short channel : W = 0.27um, L = 0.18um at  |Vds| = 1.8V')
plt.plot(x,y)
plt.grid(True, which="both", ls="-")

plt.xlabel('-Vgs (volts)')
plt.ylabel('-Id (in A)')
# Out:
# Text(0, 0.5, '-Id (in A)')

# %%
#############
# Q4.    4.d.4
import numpy as np
f = 'l.dat'
x = np.loadtxt(f,usecols = 0)
y = np.loadtxt(f,usecols = 1)
x = np.abs(x)
y = np.abs(y)

plt.yscale('log')
plt.title('pmos long channel : W = 15um, L = 10um at  |Vds| = 1.8V')
plt.plot(x,y)
plt.grid(True, which="both", ls="-")

plt.xlabel('-Vgs (volts)')
plt.ylabel('-Id (in A)')
# Out:
# Text(0, 0.5, '-Id (in A)')

# %%
#############
# Q4.    5.d
import numpy as np
f1 = '5.a.dat'


x = np.loadtxt(f1,usecols = 0)
y = np.loadtxt(f1,usecols = 1)

#plt.yscale('log')
plt.title('Vout plot for a dc input with t_r = 0s')
plt.grid()


plt.plot(x,y)

plt.scatter(0.69*1e-9,0.5,color = 'r')


plt.xlabel('t (ns)')
plt.ylabel('Vout (in V)')
plt.show()
plt.figure()

# %%
#### 5d

x = np.array([10e-12,100e-12,250e-12,500e-12,1e-9,2e-9,5e-9,8e-9,10e-9])
y = np.array( [0.7e-9 , 7.4e-10 , 8.2e-10, 0.95e-9,1.23e-9,1.84e-9,3.46e-9,5e-9,6e-9])

x_cap = x/2
y_cap = (y - x_cap)*1e9
x = x*1e12
print(y_cap)
#plt.xlim(10,1e+4)
#plt.ylim(2e-1,10e-1)
plt.scatter(x,y_cap,color = 'r')
plt.plot(x,y_cap)
plt.title('Propagation Delay vs input rise time in a RC crkt')
plt.xlabel('tr_in (ps)')
plt.ylabel(' "tp"  (ns)')
plt.figure()
# Out:
# [0.695 0.69  0.695 0.7   0.73  0.84  0.96  1.    1.   ]
